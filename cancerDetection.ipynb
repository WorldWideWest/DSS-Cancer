# %% [markdown]
# ## Pozivanje relevantnih biblioteka

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2 as cv

import os
import torch
import torchvision

from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid

from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader


from dataGeathering import DataImport

# %%
torch.__version__
# Out:
# '1.7.1+cpu'

# %% [markdown]
# ## Pozivanje fotografija u specijalnu strukturu podataka

# %%
dataImport = DataImport()
training = dataImport.Import("training")
validation = dataImport.Import("validation")
testing = dataImport.Import("testing")

# %%
validation
# Out:
# Dataset ImageFolder
#     Number of datapoints: 7069
#     Root location: ./dataSet/validation
#     StandardTransform
# Transform: ToTensor()

# %%
print(f"Klase treniranja{training.classes}")
print(f"Klase validacije{validation.classes}")
print(f"Klase testiranja{testing.classes}")
# Out:
# Klase treniranja['0', '1']
# Klase validacije['0', '1']
# Klase testiranja['0', '1']

# %% [markdown]
# ## 0 - Benign - zdrave ćelije
# ## 1 - Malignant - zaražene ćelije

# %%
imgTraining, labelTraining = training[0]
imgValidation, labelValidation = validation[0]
imgTesting, labelTesting = testing[0]

# %%
def Indicies(dataSet):
    indicies = []
    for i in range(len(dataSet)):
        indicies.append(i)
    return indicies

# %%
trainingData = Indicies(training)
validationData = Indicies(validation)
testing = Indicies(testing)

# %%
batchSize = 32

trainingSampler = SubsetRandomSampler(trainingData)
trainingDataLoader = DataLoader(training, batchSize, sampler = trainingSampler)

validationSampler = SubsetRandomSampler(validationData)
validationDataLoader = DataLoader(training, batchSize, sampler = validationSampler)

# %%
dataImport.ShowGrid(trainingDataLoader)

# %%
dataImport.ShowGrid(validationDataLoader)
